# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
channels = np.arange(0, 20)  # 20 channels
model_mae = [0.4069, 0.0701, 0.6143, 0.4258, 0.4243, 0.0324, 0.6414, 0.4292, 0.4840, 0.0281, 0.6530, 0.3987, 0.5420, 0.0708, 0.5669, 0.4149, 0.2360, 0.2124, 0.2241, 0.3458]
benchmark_mae = [0.4043, 0.1062, 0.6451, 0.4344, 0.4236, 0.0401, 0.6630, 0.4368, 0.4825, 0.0285, 0.6535, 0.4009, 0.5427, 0.0682, 0.5714, 0.4150, 0.2633, 0.2862, 0.2279, 0.3440]

bar_width = 0.35
index = np.arange(len(channels))

plt.figure(figsize=(10, 6))

# Plotting bars side by side
plt.bar(index, model_mae, bar_width, color='lightskyblue', label='model_8 MAE')
plt.bar(index + bar_width, benchmark_mae, bar_width, color='lightsalmon', label='benchmark MAE')

plt.xlabel('Canali')
plt.ylabel('MAE [rad]')
plt.xticks(index + bar_width / 2, channels)  # Center the ticks between bars
plt.legend()
plt.grid(axis='y')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
channels = [0, 1, 4, 5, 8, 9, 12, 13, 16, 17]  # 10 channels
model_mae = [0.3991, 0.0703, 0.4246, 0.0338, 0.4863, 0.0301, 0.5358, 0.0707, 0.2341, 0.2090]
benchmark_mae = [0.4077, 0.0701, 0.4244, 0.0325, 0.4853, 0.0273, 0.5407, 0.0715, 0.2486, 0.2200]

bar_width = 0.35
index = np.arange(len(channels))

plt.figure(figsize=(10, 6))

# Plotting bars side by side
plt.bar(index, model_mae, bar_width, color='lightskyblue', label='model_3 MAE')
plt.bar(index + bar_width, benchmark_mae, bar_width, color='lightsalmon', label='benchmark MAE')

plt.xlabel('Canali')
plt.ylabel('MAE [rad]')
plt.xticks(index + bar_width / 2, channels)  # Center the ticks between bars
plt.legend()
plt.grid(axis='y')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
channels = np.arange(0, 20)  # 20 channels
model_mae = [0.4090, 0.0701, 0.6346, 0.4380, 0.4235, 0.0334, 0.6541, 0.4367, 0.4829, 0.0302, 0.6526, 0.3997, 0.5437, 0.0694, 0.5788, 0.4217, 0.2336, 0.2077, 0.2277, 0.3468]
benchmark_mae = [0.4036, 0.1066, 0.6390, 0.4303, 0.4238, 0.0405, 0.6598, 0.4348, 0.4827, 0.0289, 0.6526, 0.4001, 0.5421, 0.0683, 0.5678, 0.4127, 0.2621, 0.2842, 0.2274, 0.3435]

bar_width = 0.35
index = np.arange(len(channels))

plt.figure(figsize=(10, 6))

# Plotting bars side by side
plt.bar(index, model_mae, bar_width, color='lightskyblue', label='model_1 MAE')
plt.bar(index + bar_width, benchmark_mae, bar_width, color='lightsalmon', label='benchmark MAE')

plt.xlabel('Canali')
plt.ylabel('MAE [rad]')
plt.xticks(index + bar_width / 2, channels)  # Center the ticks between bars
plt.legend()
plt.grid(axis='y')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
channels = [0, 1, 4, 5, 8, 9, 12, 13, 16, 17]  # 10 channels
model_mae = [0.4056, 0.0700, 0.4241, 0.0335, 0.4841, 0.0302, 0.5408, 0.0699, 0.2339, 0.2092]
benchmark_mae = [0.4075, 0.0706, 0.4244, 0.0328, 0.4856, 0.0273, 0.5397, 0.0728, 0.2436, 0.2171]

bar_width = 0.35
index = np.arange(len(channels))

plt.figure(figsize=(10, 6))

# Plotting bars side by side
plt.bar(index, model_mae, bar_width, color='lightskyblue', label='model_2 MAE')
plt.bar(index + bar_width, benchmark_mae, bar_width, color='lightsalmon', label='benchmark MAE')

plt.xlabel('Canali')
plt.ylabel('MAE [rad]')
plt.xticks(index + bar_width / 2, channels)  # Center the ticks between bars
plt.legend()
plt.grid(axis='y')

plt.show()
